# %% [markdown]
# <a href="https://colab.research.google.com/github/Lordvaderani/Machine-Learning-Driven-Quantum-Architecture-Search-for-Optimized-VQE-Ansatzes/blob/main/earning_Driven_Quantum_Architecture_Search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
